# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym

# %%
x = np.arange(-10,10, 1)
y = 1 / (x - 1)

# plt.xlim(-2,1)
plt.plot(x,y)
# Out:
# /var/folders/sm/c_j3r_hj0f54t97nvw00kx7c0000gn/T/ipykernel_20331/1130280838.py:2: RuntimeWarning: divide by zero encountered in divide
#   y = 1 / (x - 1)

# %%
np.sin(120)
# Out:
# 0.5806111842123143

# %%
# 2sin(theta) + 5
theta = sym.symbols('theta')
exp = 2*sym.sin(theta)+5

sym.plot(exp, ylim=[0, 8])

# %%
x = sym.symbols('x')

exp = sym.Abs(x)*sym.cos(x)
sym.plot(exp)

# %%
exp1 = sym.sin(2*theta) + theta
sym.plot(exp1)

# %%
exp2 = sym.exp(-(x**2))
sym.plot(exp2)

# %%
sym.plot(exp2*sym.tan(x), ylim=[-2, 2,])

exp2*sym.tan(x)
# Out:
# exp(-x**2)*tan(x)

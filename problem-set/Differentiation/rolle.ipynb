# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace((np.pi / 2), (3*np.pi / 2))
def fx(x):
    return np.abs(np.sin(x))

# lets check f at the two points
print('f(a)', fx(np.pi / 2))
print('f(c)', fx((3*np.pi / 2)))

df = np.abs(np.cos(x))

plt.plot(df)
# Out:
# f(a) 1.0
# f(c) 1.0
